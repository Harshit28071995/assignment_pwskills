# %%
Q1: What are the Probability Mass Function (PMF) and Probability Density Function (PDF)? Explain with
an example.
Probability Mass Function (PMF):

The PMF is a function that gives the probability that a discrete random variable is exactly equal to some value.
It is used for discrete random variables, where the set of possible outcomes is countable.
Probability Density Function (PDF):

The PDF is a function that describes the likelihood of a continuous random variable to take on a particular value.
It is used for continuous random variables, where the set of possible outcomes is uncountable.
The area under the PDF curve over an interval represents the probability that the random variable falls within that interval.
Q2: What is Cumulative Density Function (CDF)? Explain with an example. Why CDF is used?
Cumulative Density Function (CDF):

The CDF of a random variable 
𝑋
X is a function that gives the probability that 
𝑋
X will take a value less than or equal to 
𝑥
x.
It is defined for both discrete and continuous random variables.
Q3: What are some examples of situations where the normal distribution might be used as a model?
Examples:

Heights of people in a specific population.
IQ scores.
Measurement errors in scientific experiments.
Stock returns in finance.
Parameters of the Normal Distribution:

Mean (μ): Determines the center of the distribution. The distribution is symmetric about the mean.
Standard Deviation (σ): Determines the spread or width of the distribution. A larger standard deviation results in a wider, flatter curve, while a smaller standard deviation results in a narrower, taller curve.
Explain how the parameters of the normal distribution relate to the shape of the distribution.
Q4: Explain the importance of Normal Distribution. Give a few real-life examples of Normal
Distribution.
Importance:

The normal distribution is a fundamental distribution in statistics because of the Central Limit Theorem, which states that the sum of a large number of independent random variables, regardless of their distribution, will tend to be normally distributed.
Many statistical methods and tests assume normality.
It provides a good approximation for various real-life phenomena.
Real-life Examples:

Heights and weights of people.
Blood pressure readings.
Test scores such as SAT, GRE, etc.
Measurement errors in physical and engineering processes.
Q5: What is Bernaulli Distribution? Give an Example. What is the difference between Bernoulli
Distribution and Binomial Distribution?
Bernoulli Distribution:

A discrete probability distribution for a random variable which has only two possible outcomes: success (1) and failure (0).
The probability of success is 
𝑝
p and failure is 
1
−
𝑝
1−p.
Example:

Tossing a fair coin (success = heads, failure = tails).
Difference between Bernoulli and Binomial Distribution:

Bernoulli Distribution: Refers to the distribution of a single trial.
Binomial Distribution: Refers to the distribution of the number of successes in 
𝑛
n independent Bernoulli trials.
Q6. Consider a dataset with a mean of 50 and a standard deviation of 10. If we assume that the dataset
is normally distributed, what is the probability that a randomly selected observation will be greater
than 60? Use the appropriate formula and show your calculations.

Q7: Explain uniform Distribution with an example.
A type of probability distribution in which all outcomes are equally likely within a given range.
For a continuous uniform distribution, the PDF is constant between the minimum value 
𝑎
a and the maximum value 
𝑏
b.

Q8: What is the z score? State the importance of the z score.
Z-score:

A measure that describes a value's position relative to the mean of a group of values.
It is expressed in terms of standard deviations from the mean.
Q9: What is Central Limit Theorem? State the significance of the Central Limit Theorem.Central Limit Theorem (CLT):

States that the distribution of the sample mean of a large number of independent, identically distributed variables approaches a normal distribution, regardless of the original distribution of the variables.
Significance:

Allows the use of normal distribution to make inferences about population parameters from sample statistics.
Provides the foundation for many statistical procedures, including hypothesis testing and confidence intervals.
Q10: State the assumptions of the Central Limit Theorem.
Independence: The sampled values must be independent of each other.
Identically Distributed: The sampled values must come from the same distribution.
Sample Size: The sample size should be sufficiently large (usually 
𝑛
≥
30
n≥30 is considered adequate).
Understanding these concepts and their applications is crucial for analyzing and interpreting statistical data accurately.
# Out:
#   Cell In[1], line 57
#     −
#     ^
# SyntaxError: invalid character '−' (U+2212)
